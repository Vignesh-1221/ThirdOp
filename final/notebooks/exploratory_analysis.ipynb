# %%
# %% [markdown]
# # EDA for IgAN Prediction
import pandas as pd
import seaborn as sns
from config import PROCESSED_DATA_PATH

# Load data
df = pd.read_csv(PROCESSED_DATA_PATH)

# %% [markdown]
# ## Class Distribution
sns.countplot(x='IgAN_Status', data=df)

# %% [markdown]
# ## Correlation Heatmap
sns.heatmap(df[FEATURES + [TARGET]].corr(), annot=True)
